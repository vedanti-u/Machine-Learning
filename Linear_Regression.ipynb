# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax

data = pd.read_csv('LR_SR.csv')
data.shape
# Out:
# (700, 2)

# %%
data.dtypes
# Out:
# x    float64
# y    float64
# dtype: object

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
data.head
# Out:
# <bound method NDFrame.head of         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]>

# %%
data.tail
# Out:
# <bound method NDFrame.tail of         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
data.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
data.isnull().count()
# Out:
# x    700
# y    700
# dtype: int64

# %%
data.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
data = data.dropna()

data_x=data.drop(['y'],axis=1)

data_x.shape
# Out:
# (699, 1)

# %%
target_y=data.drop(['x'],axis=1)
target_y.shape
# Out:
# (699, 1)

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [699 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(data_x,target_y,test_size=0.2) #spiltted into 20:80 ratio

# %%
len(X_train)
# Out:
# 559

# %%
len(X_test)
# Out:
# 140

# %%
len(y_train)
# Out:
# 559

# %%
len(y_test)
# Out:
# 140

# %%
X_train.shape
# Out:
# (559, 1)

# %%
X_test.shape
# Out:
# (140, 1)

# %%
y_train.shape
# Out:
# (559, 1)

# %%
y_test.shape
# Out:
# (140, 1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
#              y
# 47   52.823908
# 362  30.606317
# 324  32.521794
# 102  47.883890
# 547  56.181315
# ..         ...
# 678  14.811068
# 690  69.717878
# 645  94.151492
# 497  60.388231
# 590  76.473409
#
# [559 rows x 1 columns]

# %%
y_predict_train1=reg.predict(X_train)
y_predict_train1     #y_predict_train1 aur #y_train same hona chahiye
# Out:
# array([[ 5.09206722e+01],
#        [ 3.09484390e+01],
#        [ 3.59414973e+01],
#        [ 4.59276139e+01],
#        [ 5.69123422e+01],
#        [ 8.97898236e+00],
#        [ 3.59414973e+01],
#        [ 9.98526437e+01],
#        [-8.52260992e-03],
#        [ 2.59553806e+01],
#        [ 7.58859638e+01],
#        [ 7.48873522e+01],
#        [ 3.49428856e+01],
#        [ 4.89234489e+01],
#        [ 1.89650990e+01],
#        [ 7.98037070e+00],
#        [ 5.98314737e+00],
#        [ 8.98665271e+01],
#        [ 5.99081772e+01],
#        [ 2.89512156e+01],
#        [ 1.49706523e+01],
#        [ 9.90089054e-01],
#        [ 3.19470506e+01],
#        [ 4.79248372e+01],
#        [ 5.19192839e+01],
#        [ 4.98453571e+00],
#        [ 2.98731238e+00],
#        [ 3.79387206e+01],
#        [ 5.09206722e+01],
#        [ 2.29595457e+01],
#        [ 1.79664873e+01],
#        [ 2.39581573e+01],
#        [ 2.49567690e+01],
#        [ 5.39165072e+01],
#        [ 2.79526040e+01],
# ...

# %%
plt.scatter(X_train,y_train,color='pink')
plt.plot(X_train,y_predict_train1,color='blue')
plt.xlabel("X_train")
plt.ylabel("y_predict_train1")
plt.show()

# %%
y_predict_test1=reg.predict(X_test)
y_predict_test1
# Out:
# array([[ 5.49151189e+01],
#        [ 9.98526437e+01],
#        [ 3.49428856e+01],
#        [ 7.48873522e+01],
#        [ 6.98175904e+00],
#        [ 5.19192839e+01],
#        [ 7.38887405e+01],
#        [ 9.48595854e+01],
#        [ 1.59692640e+01],
#        [ 7.18915172e+01],
#        [ 6.29040122e+01],
#        [ 7.78831871e+01],
#        [ 7.28901288e+01],
#        [ 4.29317789e+01],
#        [ 9.18637504e+01],
#        [ 8.88679154e+01],
#        [ 5.69123422e+01],
#        [ 1.09762057e+01],
#        [ 2.99498273e+01],
#        [ 4.98453571e+00],
#        [ 7.78831871e+01],
#        [ 2.49567690e+01],
#        [ 9.88540321e+01],
#        [ 2.09623223e+01],
#        [ 6.09067889e+01],
#        [ 6.68984588e+01],
#        [ 8.88679154e+01],
#        [ 9.58581971e+01],
#        [ 4.39303906e+01],
#        [ 1.89650990e+01],
#        [ 9.08651388e+01],
#        [ 9.88540321e+01],
#        [ 3.19470506e+01],
#        [ 5.79109539e+01],
#        [ 8.38748571e+01],
# ...

# %%
plt.scatter(X_test,y_test,color='purple')
plt.plot(X_test,y_predict_test1,color='green')
plt.xlabel("X_test")
plt.ylabel("y_predict_test1")
plt.show()

# %%
plt.scatter(X_train,y_train,color='pink')

# %%
reg.score(X_train,y_train)
# Out:
# 0.9908528550464036

# %%
reg.score(X_train,y_predict_train1)
# Out:
# 1.0

# %%
reg.score(y_train,y_predict_train1)
# Out:
# 0.9907848628674839

# %%
LinearRegression()

c=reg.intercept_
c
# Out:
# array([-0.00852261])

# %%
m=reg.coef_
m
# Out:
# array([[0.99861166]])

# %%
y_predict_train = c+m*X_train   #this is alternate method
y_predict_train
# Out:
#              x
# 47   50.920672
# 362  30.948439
# 324  35.941497
# 102  45.927614
# 547  56.912342
# ..         ...
# 678  12.973429
# 690  72.890129
# 645  96.856809
# 497  60.906789
# 590  69.894294
#
# [559 rows x 1 columns]

# %% [markdown]
# ## INSURANCE DATASET

# %%
import pandas as pd
df=pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().count()
# Out:
# age         1338
# sex         1338
# bmi         1338
# children    1338
# smoker      1338
# region      1338
# charges     1338
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['sex'] = df['sex'].replace(['male', 'female'],[0, 1])

# %%
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    0  30.970         3     no  northwest  10600.54830
# 1334   18    1  31.920         0     no  northeast   2205.98080
# 1335   18    1  36.850         0     no  southeast   1629.83350
# 1336   21    1  25.800         0     no  southwest   2007.94500
# 1337   61    1  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['smoker'] = df['smoker'].replace(['yes', 'no'],[1, 0])

# %%
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
gk = df.groupby('region')

gk.first()
# Out:
#            age  sex     bmi  children  smoker      charges
# region
# northeast   37    0  29.830         2       0   6406.41070
# northwest   33    0  22.705         0       0  21984.47061
# southeast   18    0  33.770         1       0   1725.55230
# southwest   19    1  27.900         0       1  16884.92400

# %%
df['region'] = df['region'].replace(['northeast', 'northwest','southeast','southwest'],[1,2,3,4])

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       4  16884.92400
# 1      18    0  33.770         1       0       3   1725.55230
# 2      28    0  33.000         3       0       3   4449.46200
# 3      33    0  22.705         0       0       2  21984.47061
# 4      32    0  28.880         0       0       2   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       0       2  10600.54830
# 1334   18    1  31.920         0       0       1   2205.98080
# 1335   18    1  36.850         0       0       3   1629.83350
# 1336   21    1  25.800         0       0       4   2007.94500
# 1337   61    1  29.070         0       1       2  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# charges     float64
# dtype: object

# %%
data = df.copy()

# %%
X=df.drop(columns='charges')

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       4
# 1      18    0  33.770         1       0       3
# 2      28    0  33.000         3       0       3
# 3      33    0  22.705         0       0       2
# 4      32    0  28.880         0       0       2
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       2
# 1334   18    1  31.920         0       0       1
# 1335   18    1  36.850         0       0       3
# 1336   21    1  25.800         0       0       4
# 1337   61    1  29.070         0       1       2
#
# [1338 rows x 6 columns]

# %%
Y=df.drop(['age','sex','bmi','children','smoker','region'],axis=1)

# %%
Y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2) #spiltted into 20:80 ratio

# %%
len(X_train)
# Out:
# 1070

# %%
X_train
# Out:
#       age  sex     bmi  children  smoker  region
# 146    46    0  30.495         3       1       2
# 173    35    1  34.800         1       0       4
# 495    20    0  27.930         0       0       1
# 606    27    1  25.175         0       0       1
# 641    42    0  28.310         3       1       2
# ...   ...  ...     ...       ...     ...     ...
# 1329   52    0  38.600         2       0       4
# 595    46    1  33.725         1       0       1
# 868    61    0  23.655         0       0       1
# 66     61    1  39.100         2       0       4
# 717    60    0  24.320         1       0       2
#
# [1070 rows x 6 columns]

# %%
y_train
# Out:
#           charges
# 146   40720.55105
# 173    5246.04700
# 495    1967.02270
# 606    3558.62025
# 641   32787.45859
# ...           ...
# 1329  10325.20600
# 595    8823.98575
# 868   13129.60345
# 66    14235.07200
# 717   13112.60480
#
# [1070 rows x 1 columns]

# %%
X_train.shape
# Out:
# (1070, 6)

# %%
y_train.shape
# Out:
# (1070, 1)

# %%
X_test.shape
# Out:
# (268, 6)

# %%
y_test.shape
# Out:
# (268, 1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict_train1=reg.predict(X_train)
y_predict_train1     #y_predict_train1 aur #y_train same hona chahiye
# Out:
# array([[34779.25083178],
#        [ 8378.94240447],
#        [ 2202.22237057],
#        ...,
#        [11067.39370773],
#        [17118.57199516],
#        [11362.28188335]])

# %%
plt.scatter(X_train,y_train,color='pink')
plt.plot(X_train,y_predict_train1,color='blue')
plt.xlabel("X_train")
plt.ylabel("y_predict_train1")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4896/1832548987.py in <module>
# ----> 1 plt.scatter(X_train,y_train,color='pink')
#       2 plt.plot(X_train,y_predict_train1,color='blue')
#       3 plt.xlabel("X_train")
#       4 plt.ylabel("y_predict_train1")
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
y_predict_test1=reg.predict(X_test)
y_predict_test1
# Out:
# array([[ 6.26331350e+03],
#        [ 8.30034834e+03],
#        [ 3.04254771e+04],
#        [ 3.06069926e+04],
#        [-1.97920463e+01],
#        [ 1.02008618e+04],
#        [ 5.69639729e+03],
#        [ 6.48396669e+03],
#        [ 3.86240728e+03],
#        [ 1.73081032e+04],
#        [ 1.69110028e+04],
#        [ 1.25470217e+04],
#        [ 8.84993306e+03],
#        [ 1.04648090e+04],
#        [ 2.65457707e+04],
#        [-5.91698613e+02],
#        [ 6.94260771e+03],
#        [-5.60156899e+02],
#        [-2.04326200e+03],
#        [ 1.06862795e+04],
#        [ 1.17309805e+04],
#        [ 1.02066478e+04],
#        [ 1.21868653e+04],
#        [ 1.30185235e+04],
#        [-1.33501857e+03],
#        [ 6.76569687e+03],
#        [ 1.24770462e+04],
#        [ 1.61878534e+03],
#        [ 1.15123508e+04],
#        [ 9.55440561e+03],
#        [ 4.95628291e+03],
#        [ 3.22505419e+04],
#        [ 9.31604561e+03],
#        [ 3.85901531e+03],
#        [ 4.50874776e+03],
# ...

# %%
plt.scatter(X_test,y_test,color='purple')
plt.plot(X_test,y_predict_test1,color='green')
plt.xlabel("X_test")
plt.ylabel("y_predict_test1")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4896/2917447861.py in <module>
# ----> 1 plt.scatter(X_test,y_test,color='purple')
#       2 plt.plot(X_test,y_predict_test1,color='green')
#       3 plt.xlabel("X_test")
#       4 plt.ylabel("y_predict_test1")
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
plt.scatter(y_test,y_predict_test1,color='purple')
plt.xlabel("y_test actual")
plt.ylabel("y_predict_test_predict1")
plt.show()

# %%
LinearRegression()

c=reg.intercept_
c
# Out:
# array([-12428.81390699])

# %%
m=reg.coef_
m
# Out:
# array([[  253.14735761,   279.20956688,   354.12171344,   635.07492496,
#         23504.18052459,  -322.53033116]])

# %%
y_predict_train = c+m*X_train   #this is alternate method
y_predict_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4896/3557837456.py in <module>
# ----> 1 y_predict_train = c+m*X_train   #this is alternate method
#       2 y_predict_train
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2030         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031     ):
# -> 2032         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2033
#    2034     # ideally we would define this to avoid the getattr checks, but
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     251
#     252     # for binary ops, use our custom dunder methods
# --> 253     result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
# ...

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_train,y_predict_train1)
r2
# Out:
# 0.7501645515408135
